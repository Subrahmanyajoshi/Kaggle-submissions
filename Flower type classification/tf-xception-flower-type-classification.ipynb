# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import glob

import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import VGG19, Xception

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
import os

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# 2022-03-29 13:30:18.854753: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2022-03-29 13:30:18.854892: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
batch_size = 256
IMAGE_SIZE = [512, 512]
num_epochs = 65

# %% [markdown]
# ## Set strategy

# %%
# Set distribution strategy to use TPUs
resolver = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
print('Found connected TPU: ', resolver.cluster_spec().as_dict()['worker'])

tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)
strategy = tf.distribute.TPUStrategy(resolver)
# Out:
# Found connected TPU:  ['10.0.0.2:8470']
# 2022-03-29 13:30:29.343862: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-03-29 13:30:29.347926: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2022-03-29 13:30:29.347966: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-03-29 13:30:29.347993: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (1d4706c4091d): /proc/driver/nvidia/version does not exist
# 2022-03-29 13:30:29.352451: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-29 13:30:29.354787: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-03-29 13:30:29.363346: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-03-29 13:30:29.404736: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2022-03-29 13:30:29.404803: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30042}
# 2022-03-29 13:30:29.423102: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2022-03-29 13:30:29.423158: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30042}
# 2022-03-29 13:30:29.424861: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:411] Started server with target: grpc://localhost:30042

# %%
AUTO = tf.data.experimental.AUTOTUNE

# %%
# TPU requires everything to be in a GCS bucket to work.

from kaggle_datasets import KaggleDatasets

GCS_DS_PATH = KaggleDatasets().get_gcs_path('tpu-getting-started')
print(GCS_DS_PATH) # what do gcs paths look like?
# Out:
# gs://kds-6a1ae5195fc22c931e638a3035ad889d8d8ca4cb7c11fc721f4f860b

# %% [markdown]
# ## Read Images

# %%
# list files
train_files = tf.io.gfile.glob(f'{GCS_DS_PATH}/tfrecords-jpeg-512x512/train/*')
val_files = tf.io.gfile.glob(f'{GCS_DS_PATH}/tfrecords-jpeg-512x512/val/*')
test_files = tf.io.gfile.glob(f'{GCS_DS_PATH}/tfrecords-jpeg-512x512/test/*')
# Out:
# 2022-03-29 13:30:39.954985: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2022-03-29 13:30:40.036741: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2022-03-29 13:30:40.106770: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.

# %%
# file name contains the number of samples in that tf record. 00-224x224-798.tfrec -> contains 798 samples.
def get_num_samples(file_list):
    count = 0 
    for file_name in file_list:
        num_sample = int(file_name.split('.tfrec')[0].rsplit('-', 1)[1])
        count += num_sample
    return count

# %% [markdown]
# ### Sizes of each dataset

# %%
train_size = get_num_samples(train_files)
val_size = get_num_samples(val_files)
test_size = get_num_samples(test_files)

print(f"Train dataset size: {train_size}")
print(f"Validation dataset size: {val_size}")
print(f"Test dataset size: {test_size}")
# Out:
# Train dataset size: 12753
# Validation dataset size: 3712
# Test dataset size: 7382

# %%
# Functions and 'classes' variable in this cell were taken from https://www.kaggle.com/code/ryanholbrook/create-your-first-submission/notebook

CLASSES = ['pink primrose',    'hard-leaved pocket orchid', 'canterbury bells', 'sweet pea',     'wild geranium',     'tiger lily',           'moon orchid',              'bird of paradise', 'monkshood',        'globe thistle',         # 00 - 09
           'snapdragon',       "colt's foot",               'king protea',      'spear thistle', 'yellow iris',       'globe-flower',         'purple coneflower',        'peruvian lily',    'balloon flower',   'giant white arum lily', # 10 - 19
           'fire lily',        'pincushion flower',         'fritillary',       'red ginger',    'grape hyacinth',    'corn poppy',           'prince of wales feathers', 'stemless gentian', 'artichoke',        'sweet william',         # 20 - 29
           'carnation',        'garden phlox',              'love in the mist', 'cosmos',        'alpine sea holly',  'ruby-lipped cattleya', 'cape flower',              'great masterwort', 'siam tulip',       'lenten rose',           # 30 - 39
           'barberton daisy',  'daffodil',                  'sword lily',       'poinsettia',    'bolero deep blue',  'wallflower',           'marigold',                 'buttercup',        'daisy',            'common dandelion',      # 40 - 49
           'petunia',          'wild pansy',                'primula',          'sunflower',     'lilac hibiscus',    'bishop of llandaff',   'gaura',                    'geranium',         'orange dahlia',    'pink-yellow dahlia',    # 50 - 59
           'cautleya spicata', 'japanese anemone',          'black-eyed susan', 'silverbush',    'californian poppy', 'osteospermum',         'spring crocus',            'iris',             'windflower',       'tree poppy',            # 60 - 69
           'gazania',          'azalea',                    'water lily',       'rose',          'thorn apple',       'morning glory',        'passion flower',           'lotus',            'toad lily',        'anthurium',             # 70 - 79
           'frangipani',       'clematis',                  'hibiscus',         'columbine',     'desert-rose',       'tree mallow',          'magnolia',                 'cyclamen ',        'watercress',       'canna lily',            # 80 - 89
           'hippeastrum ',     'bee balm',                  'pink quill',       'foxglove',      'bougainvillea',     'camellia',             'mallow',                   'mexican petunia',  'bromelia',         'blanket flower',        # 90 - 99
           'trumpet creeper',  'blackberry lily',           'common tulip',     'wild rose']                                                                                                                                               # 100 - 102

def data_augment(image, label):
    # Thanks to the dataset.prefetch(AUTO)
    # statement in the next function (below), this happens essentially
    # for free on TPU. Data pipeline code is executed on the "CPU"
    # part of the TPU while the TPU itself is computing gradients.
    image = tf.image.random_flip_left_right(image)
    #image = tf.image.random_saturation(image, 0, 2)
    return image, label   

def decode_image(image_data):
    image = tf.image.decode_jpeg(image_data, channels=3)
    image = tf.cast(image, tf.float32) / 255.0  # convert image to floats in [0, 1] range
    image = tf.reshape(image, [*IMAGE_SIZE, 3]) # explicit size needed for TPU
    return image

def read_labeled_tfrecord(example):
    LABELED_TFREC_FORMAT = {
        "image": tf.io.FixedLenFeature([], tf.string), # tf.string means bytestring
        "class": tf.io.FixedLenFeature([], tf.int64),  # shape [] means single element
    }
    example = tf.io.parse_single_example(example, LABELED_TFREC_FORMAT)
    image = decode_image(example['image'])
    label = tf.cast(example['class'], tf.int32)
    return image, label # returns a dataset of (image, label) pairs

def read_unlabeled_tfrecord(example):
    UNLABELED_TFREC_FORMAT = {
        "image": tf.io.FixedLenFeature([], tf.string), # tf.string means bytestring
        "id": tf.io.FixedLenFeature([], tf.string),  # shape [] means single element
        # class is missing, this competitions's challenge is to predict flower classes for the test dataset
    }
    example = tf.io.parse_single_example(example, UNLABELED_TFREC_FORMAT)
    image = decode_image(example['image'])
    idnum = example['id']
    return image, idnum # returns a dataset of image(s)

# %% [markdown]
# ## Create TF data objects

# %%
train_dataset = tf.data.TFRecordDataset(train_files, num_parallel_reads=AUTO)
test_dataset = tf.data.TFRecordDataset(test_files, num_parallel_reads=AUTO)
val_dataset = tf.data.TFRecordDataset(val_files, num_parallel_reads=AUTO)

# %%
train_dataset = train_dataset.map(read_labeled_tfrecord)
train_dataset = train_dataset.map(data_augment, num_parallel_calls=AUTO)
train_dataset = train_dataset.shuffle(buffer_size=batch_size)
train_dataset = train_dataset.repeat()
train_dataset = train_dataset.batch(batch_size=batch_size)
train_dataset = train_dataset.prefetch(buffer_size=batch_size)

# %%
val_dataset = val_dataset.map(read_labeled_tfrecord)
val_dataset = val_dataset.batch(batch_size=batch_size)
val_dataset = val_dataset.prefetch(buffer_size=batch_size)

# %%
test_dataset = test_dataset.map(read_unlabeled_tfrecord)
test_dataset = test_dataset.prefetch(buffer_size=batch_size)

# %% [markdown]
# ## Build model

# %%
# VGG19 model
def create_vgg19_model():
    base_model = VGG19(
        weights='imagenet',
        input_shape=(512, 512, 3),
        include_top=False
    )
    base_model.trainable = False
    inputs = tf.keras.Input(shape=(512, 512, 3))
    x = base_model(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Flatten()(x)
    x = layers.Dense(4112, activation='relu')(x)
    x = layers.Dense(2056, activation='relu')(x)
    x = layers.Dense(1024, activation='relu')(x)
    x = layers.Dense(512, activation='relu')(x)
    outputs = layers.Dense(len(CLASSES), activation='softmax')(x)
    model = tf.keras.Model(inputs, outputs)

    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])

    return model

# %%
# Xception model
def create_xception_model():
    base_model = Xception(
    weights='imagenet',  # Load weights pre-trained on ImageNet.
    input_shape=(512, 512, 3),
    include_top=False)
    
    base_model.trainable = False
    inputs = tf.keras.Input(shape=(512, 512, 3))
    x = base_model(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Flatten()(x)
    x = layers.Dense(4112, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(4112, activation='relu')(x)
    outputs = layers.Dense(len(CLASSES), activation='softmax')(x)
    model = tf.keras.Model(inputs, outputs)

    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])

    return model

# %% [markdown]
# ## Callbacks

# %%
cp_callback = ModelCheckpoint(filepath='flower_model_xception.hdf5',
                              monitor='val_sparse_categorical_accuracy',
                              save_freq='epoch', verbose=1, period=1,
                              save_best_only=True, save_weights_only=True)

early_stopping = EarlyStopping(monitor='val_sparse_categorical_accuracy',
                               verbose=1, patience=5)

# %% [markdown]
# ## Train

# %%
with strategy.scope():
    batch_size = batch_size * strategy.num_replicas_in_sync
    steps_per_epoch = int(train_size / batch_size)*2
    model = create_xception_model()
    history = model.fit(
                train_dataset, 
                validation_data=val_dataset,
                epochs=num_epochs,
                steps_per_epoch=steps_per_epoch,
                callbacks=[cp_callback, early_stopping])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# Epoch 1/65
# 12/12 [==============================] - 56s 3s/step - loss: 4.2503 - sparse_categorical_accuracy: 0.1198 - val_loss: 3.0252 - val_sparse_categorical_accuracy: 0.3200
# 2022-03-29 13:32:15.183873: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 15437, Output num: 1
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1648560735.180529564","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 15437, Output num: 1","grpc_status":3}
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.32004, saving model to flower_model_vgg19.hdf5
# Epoch 2/65
# 12/12 [==============================] - 26s 2s/step - loss: 2.8108 - sparse_categorical_accuracy: 0.3636 - val_loss: 2.1440 - val_sparse_categorical_accuracy: 0.4817
#
# Epoch 00002: val_sparse_categorical_accuracy improved from 0.32004 to 0.48168, saving model to flower_model_vgg19.hdf5
# Epoch 3/65
# 12/12 [==============================] - 26s 2s/step - loss: 2.0629 - sparse_categorical_accuracy: 0.5011 - val_loss: 1.7388 - val_sparse_categorical_accuracy: 0.5574
#
# Epoch 00003: val_sparse_categorical_accuracy improved from 0.48168 to 0.55738, saving model to flower_model_vgg19.hdf5
# Epoch 4/65
# 12/12 [==============================] - 26s 2s/step - loss: 1.7922 - sparse_categorical_accuracy: 0.5288 - val_loss: 1.4779 - val_sparse_categorical_accuracy: 0.6193
#
# Epoch 00004: val_sparse_categorical_accuracy improved from 0.55738 to 0.61934, saving model to flower_model_vgg19.hdf5
# Epoch 5/65
# 12/12 [==============================] - 26s 2s/step - loss: 1.4827 - sparse_categorical_accuracy: 0.6246 - val_loss: 1.2900 - val_sparse_categorical_accuracy: 0.6614
#
# Epoch 00005: val_sparse_categorical_accuracy improved from 0.61934 to 0.66137, saving model to flower_model_vgg19.hdf5
# Epoch 6/65
# 12/12 [==============================] - 27s 2s/step - loss: 1.3297 - sparse_categorical_accuracy: 0.6399 - val_loss: 1.1678 - val_sparse_categorical_accuracy: 0.6950
#
# Epoch 00006: val_sparse_categorical_accuracy improved from 0.66137 to 0.69504, saving model to flower_model_vgg19.hdf5
# Epoch 7/65
# 12/12 [==============================] - 26s 2s/step - loss: 1.1618 - sparse_categorical_accuracy: 0.6793 - val_loss: 1.1157 - val_sparse_categorical_accuracy: 0.7088
#
# Epoch 00007: val_sparse_categorical_accuracy improved from 0.69504 to 0.70878, saving model to flower_model_vgg19.hdf5
# Epoch 8/65
# 12/12 [==============================] - 26s 2s/step - loss: 1.1163 - sparse_categorical_accuracy: 0.6865 - val_loss: 1.0555 - val_sparse_categorical_accuracy: 0.7161
#
# Epoch 00008: val_sparse_categorical_accuracy improved from 0.70878 to 0.71606, saving model to flower_model_vgg19.hdf5
# Epoch 9/65
# 12/12 [==============================] - 27s 2s/step - loss: 1.0198 - sparse_categorical_accuracy: 0.7288 - val_loss: 0.9816 - val_sparse_categorical_accuracy: 0.7435
#
# Epoch 00009: val_sparse_categorical_accuracy improved from 0.71606 to 0.74353, saving model to flower_model_vgg19.hdf5
# Epoch 10/65
# 12/12 [==============================] - 27s 2s/step - loss: 0.9927 - sparse_categorical_accuracy: 0.7237 - val_loss: 0.9692 - val_sparse_categorical_accuracy: 0.7481
#
# Epoch 00010: val_sparse_categorical_accuracy improved from 0.74353 to 0.74811, saving model to flower_model_vgg19.hdf5
# Epoch 11/65
# 12/12 [==============================] - 27s 2s/step - loss: 0.8624 - sparse_categorical_accuracy: 0.7728 - val_loss: 0.9026 - val_sparse_categorical_accuracy: 0.7578
#
# Epoch 00011: val_sparse_categorical_accuracy improved from 0.74811 to 0.75781, saving model to flower_model_vgg19.hdf5
# Epoch 12/65
# 12/12 [==============================] - 26s 2s/step - loss: 0.8639 - sparse_categorical_accuracy: 0.7537 - val_loss: 0.8567 - val_sparse_categorical_accuracy: 0.7694
#
# Epoch 00012: val_sparse_categorical_accuracy improved from 0.75781 to 0.76940, saving model to flower_model_vgg19.hdf5
# Epoch 13/65
# 12/12 [==============================] - 27s 2s/step - loss: 0.7809 - sparse_categorical_accuracy: 0.7843 - val_loss: 0.8638 - val_sparse_categorical_accuracy: 0.7710
#
# Epoch 00013: val_sparse_categorical_accuracy improved from 0.76940 to 0.77101, saving model to flower_model_vgg19.hdf5
# Epoch 14/65
# 12/12 [==============================] - 27s 2s/step - loss: 0.8018 - sparse_categorical_accuracy: 0.7707 - val_loss: 0.8504 - val_sparse_categorical_accuracy: 0.7775
#
# Epoch 00014: val_sparse_categorical_accuracy improved from 0.77101 to 0.77748, saving model to flower_model_vgg19.hdf5
# Epoch 15/65
# 12/12 [==============================] - 26s 2s/step - loss: 0.7111 - sparse_categorical_accuracy: 0.8019 - val_loss: 0.8152 - val_sparse_categorical_accuracy: 0.7874
#
# Epoch 00015: val_sparse_categorical_accuracy improved from 0.77748 to 0.78745, saving model to flower_model_vgg19.hdf5
# Epoch 16/65
# 12/12 [==============================] - 26s 2s/step - loss: 0.7357 - sparse_categorical_accuracy: 0.7874 - val_loss: 0.8084 - val_sparse_categorical_accuracy: 0.7818
#
# Epoch 00016: val_sparse_categorical_accuracy did not improve from 0.78745
# Epoch 17/65
# 12/12 [==============================] - 26s 2s/step - loss: 0.6376 - sparse_categorical_accuracy: 0.8189 - val_loss: 0.7826 - val_sparse_categorical_accuracy: 0.7966
#
# Epoch 00017: val_sparse_categorical_accuracy improved from 0.78745 to 0.79661, saving model to flower_model_vgg19.hdf5
# Epoch 18/65
# 12/12 [==============================] - 26s 2s/step - loss: 0.6729 - sparse_categorical_accuracy: 0.8049 - val_loss: 0.8527 - val_sparse_categorical_accuracy: 0.7759
#
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.79661
# Epoch 19/65
# 12/12 [==============================] - 27s 2s/step - loss: 0.6809 - sparse_categorical_accuracy: 0.8066 - val_loss: 0.7807 - val_sparse_categorical_accuracy: 0.7883
#
# Epoch 00019: val_sparse_categorical_accuracy did not improve from 0.79661
# Epoch 20/65
# 12/12 [==============================] - 26s 2s/step - loss: 0.5768 - sparse_categorical_accuracy: 0.8388 - val_loss: 0.7254 - val_sparse_categorical_accuracy: 0.8082
#
# Epoch 00020: val_sparse_categorical_accuracy improved from 0.79661 to 0.80819, saving model to flower_model_vgg19.hdf5
# Epoch 21/65
# 12/12 [==============================] - 24s 2s/step - loss: 0.5637 - sparse_categorical_accuracy: 0.8274 - val_loss: 0.7307 - val_sparse_categorical_accuracy: 0.8136
#
# Epoch 00021: val_sparse_categorical_accuracy improved from 0.80819 to 0.81358, saving model to flower_model_vgg19.hdf5
# Epoch 22/65
# 12/12 [==============================] - 23s 2s/step - loss: 0.6275 - sparse_categorical_accuracy: 0.8167 - val_loss: 0.7386 - val_sparse_categorical_accuracy: 0.8093
#
# Epoch 00022: val_sparse_categorical_accuracy did not improve from 0.81358
# Epoch 23/65
# 12/12 [==============================] - 24s 2s/step - loss: 0.5472 - sparse_categorical_accuracy: 0.8353 - val_loss: 0.7258 - val_sparse_categorical_accuracy: 0.8106
#
# Epoch 00023: val_sparse_categorical_accuracy did not improve from 0.81358
# Epoch 24/65
# 12/12 [==============================] - 23s 2s/step - loss: 0.5097 - sparse_categorical_accuracy: 0.8491 - val_loss: 0.7375 - val_sparse_categorical_accuracy: 0.8082
#
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.81358
# Epoch 25/65
# 12/12 [==============================] - 25s 2s/step - loss: 0.4887 - sparse_categorical_accuracy: 0.8478 - val_loss: 0.7066 - val_sparse_categorical_accuracy: 0.8125
#
# Epoch 00025: val_sparse_categorical_accuracy did not improve from 0.81358
# Epoch 26/65
# 12/12 [==============================] - 24s 2s/step - loss: 0.5202 - sparse_categorical_accuracy: 0.8480 - val_loss: 0.7370 - val_sparse_categorical_accuracy: 0.8047
#
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.81358
# Epoch 00026: early stopping

# %%
plt.plot(history.history['loss'], label='train_loss') 
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['sparse_categorical_accuracy'], label='train_accuracy')
plt.plot(history.history['val_sparse_categorical_accuracy'], label='val_accuracy')
plt.legend() 
plt.show()

# %%
model = create_xception_model()
model.load_weights('flower_model_xception.hdf5')

# %%
results = {'id': [], 'label': []}

# %% [markdown]
# ## Test

# %%
def predict(element):
    image = element[0]
    id_ = tf.keras.backend.get_value(element[1]).decode("utf-8")
    result = list(model.predict(np.array([image]))[0])
    max_pred = max(result)
    result = result.index(max_pred)
    results['id'].append(id_)
    results['label'].append(result)

# %%
count = 0
for row in test_dataset: 
    image = row[0]
    id_ = tf.keras.backend.get_value(row[1]).decode("utf-8")
    result = list(model.predict(np.array([image]))[0])
    max_pred = max(result) 
    result = result.index(max_pred) 
    results['id'].append(id_)
    results['label'].append(result)
    count += 1 
    if (count % 500) == 0:
        print(f"Finished predicting {count} images")
# Out:
# Finished predicting 500 images
# Finished predicting 1000 images
# Finished predicting 1500 images
# Finished predicting 2000 images
# Finished predicting 2500 images
# Finished predicting 3000 images
# Finished predicting 3500 images
# Finished predicting 4000 images
# Finished predicting 4500 images
# Finished predicting 5000 images
# Finished predicting 5500 images
# Finished predicting 6000 images
# Finished predicting 6500 images
# Finished predicting 7000 images
# 2022-03-29 14:11:08.887958: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 254336, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1648563068.887658397","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 254336, Output num: 0","grpc_status":3}

# %%
results_df = pd.DataFrame(results)
results_df.to_csv('submission.csv', index=False)
